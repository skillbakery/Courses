# %%
# %%capture
# !pip install -U openai pydantic langchain langchain-openai tiktoken faiss-cpu

# %%
import os
import getpass
from langchain.globals import set_verbose

set_verbose(True)

# %%
os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter Your OpenAI API Key:")
# Out:
# Enter Your OpenAI API Key:··········

# %% [markdown]
# # ⛓️ What are Chains in LangChain?
#
# **In one sentence: A chain is an end-to-end wrapper around multiple individual components which are executed in a defined order.**
#
# **Quick Guide to Chains in LangChain:**
#
# - Chains link multiple processes in a set sequence to create complex applications.
# - They're useful for:
#   - Dividing complicated tasks into simpler steps.
#   - Maintaining context and memory across different steps.
#   - Adding custom processing or checks between steps.
#   - Simplifying the debugging of multi-step operations.
#
# **Basic Chain Types:**
#
# - **LLMChain**: Combines several language model calls.
# - **RouterChain**: Directs tasks to different chains based on set conditions.
# - **SimpleSequentialChain**: Executes chains one after another.
# - **TransformChain**: Alters data between chain steps.
#
# Chains integrate various components into a cohesive flow, enhancing the capabilities and flexibility of language model applications.

# %% [markdown]
# # 🗣️ LLMChain

# %%
from langchain_openai import ChatOpenAI
from langchain.prompts import PromptTemplate

# Initialize ChatOpenAI without the explicit openai_api_base unless necessary for your environment
# The default API base should work for most users.
llm = ChatOpenAI(model_name="gpt-4", temperature=0)

prompt = PromptTemplate(
    input_variables=["topic"],
    template = "Create a humorous, parody-style rhyme about: {topic}"
)

# using LCEL
chain = prompt | llm

result = chain.invoke({"topic": "spicy sushi soda"})
print(result.content)
# Out:
# (Verse 1)
# In the land of the rising sun, where the cherry blossoms float,
# There's a curious concoction, that's got everyone's vote.
# It's not your typical beverage, not your average cola,
# It's a fiery fusion, they call spicy sushi soda.
#
# (Chorus)
# Spicy sushi soda, it's a wild ride,
# A tsunami of flavors, that you can't hide.
# Wasabi and ginger, with a fizzy pop,
# Once you take a sip, you just can't stop.
#
# (Verse 2)
# It's got a kick like a karate chop, a punch like a sumo,
# It's hotter than a dragon's breath, cooler than a kimono.
# It's a sushi chef's secret, a samurai's treasure,
# This spicy sushi soda, it's a taste beyond measure.
#
# (Chorus)
# Spicy sushi soda, it's a taste sensation,
# A culinary creation, that's sweeping the nation.
# With a hint of soy sauce, and a dash of sake,
# It's a flavor explosion, that's oh so wacky.
#
# (Bridge)
# So raise your glass high, give a hearty "Kanpai!"
# To the spicy sushi soda, under the Tokyo sky.
# It's a taste adventure, a gastronomic oddity,
# A fusion of flavors, in perfect harmony.
#
# (Chorus)
# Spicy sushi soda, it's a daring delight,
# A beverage that's bold, that'll light up your night.
# So here's to the brave, who dare to be bold,
# With spicy sushi soda, let the flavors unfold.
#
# (Outro)
# So if you're feeling adventurous, and you're ready to go,
# Try the spicy sushi soda, let your taste buds glow.
# It's a rollercoaster of flavor, a culinary quirk,
# This spicy sushi soda, it's a masterpiece of work.

# %%
from langchain.schema import StrOutputParser

chain = prompt | llm | StrOutputParser()

chain.invoke({"topic": "spicy sushi soda"})
# Out:
# "(Verse 1)\nIn the land of the rising sun, where the cherry blossoms float,\nThere's a curious concoction, that's got everyone's vote.\nIt's not your typical beverage, not your average cola,\nIt's a fiery fusion, they call spicy sushi soda.\n\n(Chorus)\nSpicy sushi soda, it's a wild ride,\nA tsunami of flavors, that you can't hide.\nWasabi and ginger, with a fizzy pop,\nOnce you take a sip, you just can't stop.\n\n(Verse 2)\nIt's got a kick like a karate chop, a punch like a sumo,\nIt's hotter than a dragon's breath, cooler than a kimono.\nIt's a sushi chef's secret, a samurai's treasure,\nThis spicy sushi soda, it's a taste beyond measure.\n\n(Chorus)\nSpicy sushi soda, it's a taste sensation,\nA culinary creation, that's sweeping the nation.\nWith a hint of soy sauce, and a dash of sake,\nIt's a flavor explosion, that's oh so wacky.\n\n(Bridge)\nSo here's to the brave, who dare to try,\nThis spicy sushi soda, under the Tokyo sky.\nIt's a gastronomic gamble, a daring delight,\nThis spicy sushi soda, it's outta sight!\n\n(Chorus)\nSpicy sushi soda, it's a wild ride,\nA tsunami of flavors, that you can't hide.\nWasabi and ginger, with a fizzy pop,\nOnce you take a sip, you just can't stop.\n\n(Outro)\nSo raise your glass high, give a hearty cheer,\nFor the spicy sushi soda, the drink of the year.\nIt's a taste adventure, a flavor fiesta,\nThis spicy sushi soda, it's the besta!"

# %%
print(chain.invoke({"topic": "spicy sushi soda"}))
# Out:
# (Verse 1)
# In the land of the rising sun, where the cherry blossoms float,
# There's a curious concoction, that's got everyone's vote.
# It's not your typical beverage, not your average cola,
# It's a fiery fusion, they call spicy sushi soda.
#
# (Chorus)
# Spicy sushi soda, it's a wild ride,
# A tsunami of flavors, that you can't hide.
# Wasabi and ginger, with a fizzy pop,
# Once you take a sip, you just can't stop.
#
# (Verse 2)
# It's got a kick like a karate chop, a punch like a sumo,
# It's hotter than a dragon's breath, cooler than a kimono.
# It's a sushi chef's secret, a samurai's elixir,
# A geisha's guilty pleasure, a ninja's favorite mixer.
#
# (Chorus)
# Spicy sushi soda, it's a taste sensation,
# A culinary creation, that's sweeping the nation.
# It's a sushi roll in a bottle, a feast in a can,
# A gastronomic gamble, for every woman and man.
#
# (Verse 3)
# So if you're feeling adventurous, if you're feeling bold,
# Try the spicy sushi soda, let the flavors unfold.
# It's a taste of Tokyo, in a carbonated brew,
# A sip of the exotic, just waiting for you.
#
# (Chorus)
# Spicy sushi soda, it's a daring delight,
# A fusion of flavors, that'll ignite your night.
# It's a sushi sensation, a fizzy fantasy,
# A spicy sushi soda, for you and me.

# %%
from langchain.prompts import ChatPromptTemplate
from langchain.schema import StrOutputParser

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are Dreggo the Rapper. You drop catchy, hilarious rhymes like a comedy king."),
        ("human", "Write a silly, parody-style rap about this funny subject: {topic}"),
    ]
)

runnable = prompt | llm | StrOutputParser()

# %%
print(runnable.invoke({"topic": "wasabi flavoured saki"}))
# Out:
# (Verse 1)
# Yo, it's Dreggo on the mic, got a story to tell,
# 'Bout a drink so wild, it'll ring your bell.
# Wasabi flavoured saki, yeah you heard it right,
# A combo so crazy, it'll ignite your night.
#
# Sippin' on that green, got my tongue on fire,
# Eyes watering, situation dire.
# It's a spicy tsunami, a wasabi wave,
# Got me dancing like a fool, no chance to behave.
#
# (Chorus)
# Wasabi saki, you're a tricky little devil,
# Turnin' up the heat, on a whole new level.
# Got me sweatin' like a pig, in a sauna suit,
# Wasabi saki, you're a hoot, absolute!
#
# (Verse 2)
# First sip, I was like, "What's this trick?"
# Taste buds doing flips, it's a spicy kick.
# Next thing I know, I'm on the dance floor,
# Wasabi saki got me begging for more.
#
# It's a green mean machine, in a tiny cup,
# One sip of this, and you're straight up.
# It's a rollercoaster ride, no safety bar,
# Wasabi saki, you're a superstar.
#
# (Chorus)
# Wasabi saki, you're a wild ride,
# Got me spinning, got nowhere to hide.
# You're a firecracker, a spicy delight,
# Wasabi saki, you're outta sight!
#
# (Outro)
# So here's to you, wasabi saki,
# You're a laugh riot, a real wacky.
# You're a taste sensation, a fiery thrill,
# Wasabi saki, you're the real deal.

# %%
for chunk in runnable.stream({"topic": "spicy sushi soda"}):
    print(chunk, end="", flush=True)
# Out:
# (Verse 1)
# Yo, yo, yo, it's Dreggo on the mic,
# Got a story to tell, it's gonna be a sight,
# Bout a drink so wild, it'll give you a fright,
# Spicy sushi soda, yeah, that's right.
#
# Now, I ain't no chef, but I got a notion,
# Mixing sushi and soda, that's a crazy potion,
# Fish in your drink, causing a commotion,
# Got your taste buds doing the locomotion.
#
# (Chorus)
# Spicy sushi soda, poppin' like a firecracker,
# Taste so wild, it's a tongue attacker,
# Wasabi and ginger, they ain't no slacker,
# Got you sweatin' like a linebacker.
#
# (Verse 2)
# Raw fish floatin' in a fizzy sea,
# Spicy sushi soda, it's a mystery,
# Who thought of this? Must be history,
# But it's got a kick, like Bruce Lee.
#
# Sip it slow, or you'll be in tears,
# It's the hottest drink in a thousand years,
# But once you try it, you'll be all cheers,
# Spicy sushi soda, conquer your fears.
#
# (Chorus)
# Spicy sushi soda, hotter than a sauna,
# Got you feelin' like you're in Tijuana,
# It's a wild ride, like Madonna,
# Spicy sushi soda, it's gonna own ya.
#
# (Outro)
# So here's to the brave, who dare to try,
# Spicy sushi soda, flying high,
# It's a taste explosion, no lie,
# Spicy sushi soda, give it a high-five.
#
# Yo, it's Dreggo, signing off with a grin,
# Spicy sushi soda, it's a win,
# Till next time, keep your chin up, chin,
# And remember, life's too short not to sin.

# %% [markdown]
# # 🔄 **Understanding Routing in LangChain**
#
# ### **Routing Concept**
# - **Purpose**: Adds structure to interactions with LLMs by guiding the flow based on previous step outcomes.
#
# - **Essence**: Determines the next step in a chain dynamically, based on the result of the previous step.
#
# ### **Methods for Routing**
# 1. ᛘ **RunnableBranch Usage**:
#    - Manages decision-making for the next step in a chain.
#
# 2. 🏭 **Custom Factory Function**:
#    - Crafts a runnable based on previous step input.
#
#    - Crucial: The function should only create a runnable, not execute it.
#
# ### **Example Application**
# - **Two-Step Sequence**:
#
#   - **Step 1**: Classifies a question into categories (literature, history, biology, philosophy, or other).
#
#   - **Step 2**: Routes the classified question to a corresponding prompt chain tailored for the identified category.
#
# 🎯 **Application Goal**: Showcase both routing methods in a practical scenario to enhance interactions with language models.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnableBranch
from langchain.prompts import PromptTemplate
ChatOpenAI(model_name="gpt-4-0125-preview")

literature_template = """You are a seasoned literature professor with decades of experience analyzing literary works. \
You have a knack for understanding complex narratives and characters and can provide insights into underlying themes and motifs.

Here is a passage or question about a literary work:
{input}
"""

literature_prompt = PromptTemplate.from_template(literature_template)


history_template = """You are a historian with extensive knowledge about world history. \
From ancient civilizations to modern times, you can provide context, insights, and explanations about historical events and figures.

Here is a question about history:
{input}
"""

history_prompt = PromptTemplate.from_template(history_template)

biology_template = """You are a biologist with a passion for understanding the intricacies of life. \
From cellular processes to ecosystem dynamics, you can elucidate biological phenomena with clarity.

Here is a question about biology:
{input}
"""

biology_prompt = PromptTemplate.from_template(biology_template)

philosophy_template = """You are a philosopher who has studied the great thinkers of the past and present. \
You enjoy discussing ethical dilemmas, existential questions, and the nature of reality.

Here is a philosophical query:
{input}
"""

philosophy_prompt = PromptTemplate.from_template(philosophy_template)

general_prompt = PromptTemplate.from_template(
    "You are a helpful assistant. Answer the question as accurately as you can.\n\n{input}"
)

# %% [markdown]
# # 🌿 **RunnableBranch Mechanics**
#
# 1. **Structure**: A list of (condition, runnable) pairs, plus a default runnable.
#
# 2. **Operation**
#    - On invocation, sequentially evaluates each condition with the given input.
#
#    - Executes the first runnable where its condition is True.
#
#    - If no condition matches, the default runnable is executed.
#
# 🔍 **Purpose**: Ensures structured decision-making in chain execution, directing the flow based on specific conditions.

# %%
prompt_branch = RunnableBranch(
    (lambda x: x["topic"] == "literature", literature_prompt),
    (lambda x: x["topic"] == "history", history_prompt),
    (lambda x: x["topic"] == "biology", biology_prompt),
    (lambda x: x["topic"] == "philosophy", philosophy_prompt),
    general_prompt,
)

# %%
from typing import Literal
from langchain.output_parsers.openai_functions import PydanticOutputFunctionsParser # Use PydanticOutputFunctionsParser
from langchain_core.utils.function_calling import convert_to_openai_function # Use convert_to_openai_function
from pydantic import BaseModel # Import BaseModel directly from pydantic

class TopicClassifier(BaseModel):
    "Classify the topic of the user question"

    topic: Literal["literature", "history", "biology", "philosophy"]
    "The topic of the user question. One of 'literature', 'history', 'biology', 'philosophy', or 'general'."


classifier_function = convert_to_openai_function(TopicClassifier) # Use convert_to_openai_function

llm = ChatOpenAI(model_name="gpt-4-0125-preview")

llm = llm.bind(
    functions=[classifier_function],
    function_call={"name": "TopicClassifier"}
)

parser = PydanticOutputFunctionsParser(pydantic_schema=TopicClassifier) # Provide schema directly

classifier_chain = llm | parser

# %%
from operator import itemgetter
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

final_chain = (
    RunnablePassthrough.assign(topic=itemgetter("input") | classifier_chain)
    | prompt_branch
    | ChatOpenAI(model_name="gpt-4-0125-preview")
    | StrOutputParser()
)

# %%
final_chain.invoke({"input": "Describe the Stoic philosophy for a good life."})
# Out:
# "Stoicism is an ancient Greek philosophy founded in Athens by Zeno of Citium in the early 3rd century BCE. It has since evolved, influencing countless individuals throughout history and remaining relevant to contemporary life. The Stoic philosophy for a good life is anchored in developing personal virtue and wisdom, understanding the nature of the world, and living in accordance with nature. Here are some key elements that describe the Stoic approach to achieving a good life:\n\n1. **Virtue as the Sole Good:** Stoics argue that the only true good is virtue (moral excellence) and that external circumstances are not inherently good or bad. According to Stoicism, a good life is achieved by living virtuously in harmony with reason. The four cardinal virtues in Stoicism are wisdom (the ability to navigate complex situations), courage (the capacity to face fears and adversities), justice (treating others fairly and kindly), and temperance (self-control and moderation).\n\n2. **Living According to Nature:** For Stoics, living according to nature means recognizing and accepting our place in the world as rational beings and living in harmony with the rational structure of the universe. This entails fulfilling our social duties, contributing to society, and understanding the natural order of things.\n\n3. **Dichotomy of Control:** A central concept in Stoicism is understanding what is within our control and what is not. Stoics emphasize focusing our energy on our thoughts, behaviors, and attitudes, which are within our control, rather than external events and the actions of others, over which we have no control. This approach helps individuals maintain inner peace and resilience in the face of life’s challenges.\n\n4. **Mindfulness and Self-Reflection:** Stoicism encourages ongoing self-examination and mindfulness. Stoics practice reflecting on their actions, thoughts, and emotions to cultivate self-awareness and ensure they are living in alignment with their principles.\n\n5. **Acceptance and Amor Fati:** Acceptance of what we cannot change and embracing one’s fate (Amor Fati) are key to Stoic philosophy. This means not just passively resigning oneself to whatever happens, but actively loving and appreciating life as it is, including both the good and the bad.\n\n6. **Practical Wisdom:** Stoicism is not purely theoretical; it's a practical philosophy meant to be lived. Stoics practice exercises that foster resilience, like contemplating impermanence (memento mori), visualizing challenges (premeditatio malorum), and practicing gratitude to temper desire and maintain a balanced perspective on life.\n\nIn practice, Stoicism teaches individuals to lead a life of equanimity, integrity, and moral clarity. By focusing on what they can control and accepting what they cannot, individuals can achieve inner peace and resilience, irrespective of external circumstances. Stoicism thus provides a timeless framework for navigating the complexities of human life and pursuing a good life through the cultivation of virtue and wisdom."

# %%
for chunk in final_chain.stream({"input": "Describe the Stoic philosophy for a good life."}):
    print(chunk, end="", flush=True)
# Out:
# Stoicism is an ancient Greek philosophy founded in Athens by Zeno of Citium in the early 3rd century BCE. It became quite influential in ancient Rome with well-known practitioners such as the philosopher Epictetus, the statesman Seneca, and the emperor Marcus Aurelius. The Stoic philosophy for a good life is rooted in the idea that virtue, the highest good, is based on knowledge. The wise live in harmony with the divine Reason (also known as Logos) that governs nature, and they understand that everything that happens is part of a rational order.
#
# In essence, Stoicism teaches that to achieve a good life, one should focus on what is within one's control and accept what is beyond it. The Stoics distinguish between things that are "up to us" and things that are "not up to us." Our opinions, impulses, desires, and aversions are considered to be within our power, while external events are beyond our control. By concentrating on our own actions and responses, we can attain a state of tranquility and freedom from suffering.
#
# Central to Stoic philosophy is the development of self-control and strength as a means of overcoming destructive emotions. Stoicism values the cultivation of virtue above all else, with the four cardinal virtues being wisdom (practical wisdom), courage, justice (treating others fairly), and temperance (moderation).
#
# Furthermore, Stoicism teaches the practice of mindfulness—paying attention to the present moment in an accepting and non-judgmental way. This is part of their broader concept of living in accordance with nature, both the nature of the universe and human nature.
#
# For Stoics, a good life is achieved by understanding the laws of nature and living in accordance with them. Happiness and contentment are found not in external possessions or pleasures, but in embracing virtue and wisdom. Despite misconceptions, Stoicism does not advocate for the suppression of emotions; rather, it encourages transforming desires to align with objective reasoning and social good.
#
# In summary, the Stoic philosophy for a good life revolves around self-control, ethical living, and understanding our place in the natural world. It teaches that by embracing virtue, practicing reason, and accepting what we cannot change, we can achieve serenity and fulfillment.

# %% [markdown]
# # 🧬 Sequential Chains
#
# **Basics of Sequential Chains:**
#
# - Sequential chains are for when you need one language model's output to become another's input.
# - They're like an assembly line, where each step's result is the starting point for the next.

# %%
from langchain_openai import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain.schema import StrOutputParser

# Initialize the language model
llm = ChatOpenAI(model_name="gpt-4-0125-preview")

# Template for the initial rap
template_one = """
You are a Punjabi Jatt rapper, like AP Dhillon or Sidhu Moosewala.

Given a topic, it is your job to spit bars of hard-hitting, gritty, dope rap.

Topic: {topic}

Rap:
"""

# Template for the diss track
template_two = """
You are an extremely competitive Punjabi Rapper.

Given the rap from another rapper, it's your job to write a diss track which
tears apart the rap and shames the original rapper.

Rap:
{rap}
"""

# Create user_input templates from the defined templates
prompt_template_one = PromptTemplate.from_template(template_one)
prompt_template_two = PromptTemplate.from_template(template_two)

# Define the operation chain
chain = (
    {"rap": prompt_template_one | llm | StrOutputParser()}
    | prompt_template_two
    | llm
    | StrOutputParser()
)

# %%
chain.invoke({"topic": "Sippin' Crown Royal and cruisin' in my red Challenger"})
# Out:
# "Yo, yo, hold up, lemme school ya, here's the real flow,\n\nYou talkin’ ‘bout Crown Royal like it's gold, bro,\nBut let me correct ya, that ain’t the boss beverage, no,\nWhen I sip, it’s the fire of ambition that I stow,\nIn my verses, sharper than any liquor's glow.\n\nRed Challenger? Please, that's child's play so basic,\nI'm in a league where even the stars find it majestic,\nMy ride, it's the thunder, the storm, undomestic,\nWhen I cruise, even the moon bows, apocalyptic.\n\nYour Jatt lifestyle, high-end, you say? Now listen,\nI'm redefining the meaning, every move, a mission,\nMy life, a legacy, beyond any comparison,\nYour braggin’, just a whisper in my era of dominion.\n\nEngine roars, red paint, moonlight’s friend,\nBut here’s where your fairy tale meets its end,\nI'm the lightning that splits night, the real trend,\nYour Challenger’s a pony, my legacy, dragons I send.\n\nCrown Royal, diamonds, pearls, your shallow smirk,\nI’m into building empires, while you just lurk,\nEach sip I take is from the chalice of hard work,\nYour tracks of Moosewala, Wallah, just a perk.\n\nYour culture, your roots, you think you're a protector,\nBut here I am, the real Punjabi culture sector,\nI don't need to sip Crown to show I'm a director,\nMy words, my flow, making me the ultimate vector.\n\nYou say you’re not a follower, but that’s hard to swallow,\nWith every line you spit, it’s clear you’re just hollow,\nIn your red Challenger, just a shadow in the shallow,\nI’m the storm you can’t outrun, the pill too hard to swallow.\n\nLiving dreams in your Challenger, you claim to take flight,\nBut I’m the comet in this rap game, blazing bright,\nYour legacy repeats? That's a humorous insight,\nMine’s written in the stars, eternal, infinite light.\n\nYeah, you think you’re alive, with spirit that thrives,\nBut I’m the force of nature, with countless lives,\nFrom Punjab to the galaxy, my essence revives,\nIn this game of life, it’s the visionary who survives.\n\nBoom, there you thought you were never stopping,\nBut here I am, your fantasy, abruptly dropping,\nYour Crown Royal, your throne, I find it flopping,\nJatt life, real essence, my throne, ever topping.\n\nSo, remember this, when you boast and rock,\nI’m the earthquake that will make your world shock,\nIn this rap battle, I’m the real lock,\nThe king of the scene, making all the talk."

# %%
for chunk in chain.stream({"topic": "Drinking Crown Royal and mobbin in my red Challenger"}):
    print(chunk, end="", flush=True)
# Out:
# **Diss Track: Throne Overthrown**
#
# (Verse 1)
# Yo, peep this, talkin’ 'bout your red Challenger, you a jester at best,
# I’m rollin’ in my empire, puttin’ all your boasts to rest.
# Claimin’ you the king, but your crown’s just tin foil,
# While I spit gold bars, my rule is royal, never soil.
# You’re sippin’ on that Crown, thinkin’ you're refined?
# But your rhymes are just as empty as the bottle, you’re behind.
#
# (Hook)
# You mobbin', you rollin', in that child’s play, sight,
# Your crown on thin ice, bout to snuff out your light.
# In your red Challenger, thinkin' you're invincible,
# I’ll break it down, show your reign’s just fictional.
#
# (Verse 2)
# Shinin' rims in the moonlight, you think it’s all so grand,
# But I’m the earthquakin’ force, turning diamonds to sand.
# Your legacy, a whisper, my dynasty screams in bass,
# You’re a footnote in history, vanished without a trace.
# Traditions you blendin', but it’s all just static,
# My flow’s revolutionary, dynamic, never plastic.
#
# (Hook)
# You’re mobbin', you’re rollin', but it’s a facade,
# Your night’s dull, my dawn’s breaking, lightning rod.
# In your red chariot, a pretender, a fake thrill,
# With each verse I spit, I conquer, I kill.
#
# (Bridge)
# Your car, your drink, claims of a fortress, a crown,
# I’m the storm that’ll crumble your castle down.
# Your symphony’s off key, my anthem's the real deal,
# I embody the strength, the power, the iron will.
#
# (Verse 3)
# While your night deepens, your rhymes fade into obscurity,
# My lyrics, my legacy, infinite, pure purity.
# It ain’t about the roads or the tales you claim to sow,
# It’s about the truth, the fire in my flow.
# With each line, I ascend, while you desperately try to see,
# In the realm of rap, I’m the ruler, I decree.
#
# (Outro)
# While you’re mobbin', rollin', to the break of dawn,
# I'm the phoenix rising, a new king born.
# Forget your Crown Royal, my spirit’s divine,
# In the hall of fame, my name will outshine.
#
# ---
# Keepin' it merciless, in every line I weave,
# Long after you’re gone, it's my name they'll believe.

# %% [markdown]
# # 🔄 **Transformation in Component Chains**
#
# 🔧 **Role of Transformation**:
#    - Adjusts inputs as they transition between different components.
#
# 🌟 **Example Scenario**:
#    - **Task**: Handle a lengthy text.
#    - **Transformation**: Filter to retain only the first three paragraphs.
#    - **Next Steps**: Pass the shortened text through a series of steps for summarization.
#
# 🎯 **Goal**: Demonstrates how transformations can effectively tailor inputs for specific processing needs in a component chain.

# %%
# !wget https://www.gutenberg.org/files/2680/2680-0.txt

with open("/content/2680-0.txt") as f:
    meditations = f.read()
# Out:
# --2025-06-26 13:42:34--  https://www.gutenberg.org/files/2680/2680-0.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 425351 (415K) [text/plain]
# Saving to: ‘2680-0.txt’
#
# 2680-0.txt          100%[===================>] 415.38K  --.-KB/s    in 0.1s
#
# 2025-06-26 13:42:35 (4.23 MB/s) - ‘2680-0.txt’ saved [425351/425351]

# %%
from langchain.schema import StrOutputParser
from langchain_openai import ChatOpenAI
from langchain.prompts import PromptTemplate

prompt = PromptTemplate.from_template("""Summarize this text: {output_text} Summary:""")

runnable = (
    {"output_text": lambda text: "\n".join(text.split("\n")[921:1021])}
    | prompt
    | ChatOpenAI(model_name="gpt-4-0125-preview")
    | StrOutputParser()
)
runnable.invoke(meditations)
# Out:
# "This text offers a philosophical guide on how to live a virtuous and content life, emphasizing the importance of acting with sincerity, humility, and integrity in all endeavors as fundamental Roman and human virtues. It encourages living each moment as if it were your last, devoid of vanity, irrational passions, hypocrisy, and selfishness, and to accept whatever fate or the divine has destined. The text underscores that happiness and a divine life are achievable by focusing on one's actions and disregarding external distractions or the opinions of others. It highlights the necessity of having a clear purpose, avoiding idle behavior, and striving for self-improvement and understanding of the natural world and one's place within it.\n\nFurthermore, it argues the philosophical point that sins of pleasure are more reprehensible than those committed in anger, reflecting a weakness of character. The text also dwells on the acceptance of death, proposing that if gods exist, they would not intend harm upon death; and if gods do not exist, life without divine providence is not desirable anyway. It reassures that the universe is ordered and just, implying that good and evil are within a person's control, and that external conditions like life, death, and fame are neutral and should not impact one’s virtue or happiness.\n\nFinally, it advocates for a reflection on the impermanence of all things, the trivial nature of worldly desires, and the essence of understanding one's true self and relationship with the divine. It concludes with the notion that fearing natural processes, such as death, is irrational, and understanding the nature of existence and one’s divine connection is crucial for a fulfilled life."

# %%
rephrase = PromptTemplate.from_template("""Rephrase this text: {output_text}
In the style of a 90s gangster rapper passionately speaking to his homies.
Rephrased:""")

runnable = (
    {"output_text": lambda text: "\n".join(text.split("\n")[921:1021])}
    | rephrase
    | ChatOpenAI(model_name="gpt-4-0125-preview")
    | StrOutputParser()
)

runnable.invoke(meditations)
# Out:
# "Alright, dig this, my crew, and listen up close, 'cause I'm 'bout to lay it down real. As a Roman, as a true soldier, and as a real one walking this earth, you gotta handle your biz with all the seriousness, love, sincerity, freedom, and straight-up fairness you got in you. And all that noise, all them worries clouding your dome, you gotta learn how to shake 'em off. You do this, stepping into each move like it’s your final play, ditching the fake front, the temper, the ego trips, and them masks we wear, especially hating on what fate or the Almighty's thrown your way. Real talk, to keep pushing forward, living that blessed life, ain't as complicated as it sounds – the gods ain’t asking for much, just to stay true to these rules.\n\nNow, listen here, soul, listen good – you beating yourself up, disrespecting your essence; time's running out for you to start valuing yourself. Your joy, your peace, it comes from within, but there you are, living on borrowed vibes, worried 'bout what others think, missing out on your real happiness.\n\nAnd why, oh why, are you letting outside stuff bug you that much? Take a minute, learn something worthwhile, stop wandering aimlessly. And watch out for that other trap, running circles, sweating over nothing because you ain't got a clear goal, a clear dream driving you. Hardly anyone’s ever drowned in sorrow by minding their own spirit. Those who ain’t steering their soul right, who let whims and not wisdom guide them, are bound to crash and burn.\n\nKeep this on the forefront of your mind – what's this universe about, and where do you fit in? Understand the connection, your role in this grand scheme, and know there ain’t nobody who can stop you from living and speaking your truth according to your own nature.\n\nTheophrastus, that sharp thinker, he got it right comparing flaws and faults. Said it straight up – the mess-ups we do outta lust are way worse than those done in anger. Anger might twist us up for a sec, but lust, man, it shows a whole level of weakness, giving into pleasure like that. He's on point saying it’s worse to fall chasing a good time than stumbling in a moment of rage. Dude’s saying, at least the angry cat had something done to him, kinda pushed into reacting, but the one chasing desires, that’s all on him.\n\nWhatever you're feeling, whatever’s on your to-do list, tackle it like you’re about to bounce from this life right here, right now. And death, if the gods are chillin’ up there, dying ain’t nothing to sweat. They ain’t out to get you. But if it turns out there ain’t no gods, or they ain’t watching, why stick around in a godless crib? Nah, there gotta be gods looking out, steering clear of real evil like vice and all that bad jazz, letting us dodge if we wanna. If there were something legit terrible they missed, they would’ve handled it, so we could avoid it too. So, all these things – life, death, props, struggles, joy, money troubles – they hit everyone, but by themselves, they ain’t good or bad, ain’t worth the hype nor the hate.\n\nThink on how quickly everything breaks down, everything goes back to the earth, and memories fade into the big ol’ timeline. These things that catch our eye, tempt us, or scare us, remember how fleeting, how shallow they really are.\n\nIt's the mark of a real one, someone with their head on straight, to see things for what they are – who's really behind the respect and status, and what dying truly means. Stripped down, it's just nature doing its thing, and being scared of that is kid stuff. Death’s part of the big picture, helping nature flow.\n\nReflect on how we connect to the divine, what piece of us angles towards the heavens, and how it feels when we’re scattered all out. That soul, caught up in a constant search, running around, it’s the saddest sight – lost, trying to find something it can’t even name.\n\nAlright, that’s the word, that's how we gotta roll. Keep your mind sharp, your soul in check, laughing in the face of fear, and w ...
